# %% [markdown]
# ## Primera Llamada al Modelo
#
# En este ejercicio, aprenderemos a realizar nuestra primera llamada a un modelo de lenguaje usando GitHub Models API.
#
# # 1. GitHub Models API - Conexión Directa con OpenAI Client
#
# ## Objetivos de Aprendizaje
# - Configurar una conexión directa con GitHub Models usando el cliente OpenAI
# - Comprender los parámetros básicos de configuración de API
# - Implementar llamadas básicas a modelos de lenguaje
# - Aplicar mejores prácticas de seguridad con API keys
#
# ## Introducción
# GitHub Models proporciona acceso a varios modelos de lenguaje mediante una API compatible con OpenAI. En este notebook aprenderemos a:
# 1. Configurar el entorno y las credenciales
# 2. Establecer una conexión con la API
# 3. Realizar llamadas básicas al modelo
# 4. Explorar diferentes parámetros de configuración
#
# ## Configuración de Variables de Entorno
#
# Antes de ejecutar el código, asegúrate de tener configuradas las siguientes variables de entorno:
#
# ```bash
# export GITHUB_BASE_URL="https://models.inference.ai.azure.com"
# export GITHUB_TOKEN="tu_token_de_github_aqui"
# ```
#
# **Mejores Prácticas de Seguridad:**
# - Nunca hardcodees API keys en el código
# - Usa variables de entorno o archivos .env
# - No compartas credenciales en repositorios públicos
# - Rota las API keys regularmente
#
# ## Instalación de Dependencias
# ```bash
# pip install openai
# ```

# %%
# Importar las bibliotecas necesarias
from openai import OpenAI
import os

# Verificar que tenemos las bibliotecas correctas
print("OpenAI library version:", __import__('openai').__version__)
print("Python version:", __import__('sys').version)

# Configuración del cliente OpenAI para GitHub Models
try:
    # Configurar el cliente con variables de entorno
    client = OpenAI(
        base_url=os.environ.get("GITHUB_BASE_URL"),
        api_key=os.environ.get("GITHUB_TOKEN")
    )
    
    # Verificar configuración (sin mostrar la API key completa por seguridad)
    print("Base URL configurada:", client.base_url)
    print("API Key configurada:", "✓" if client.api_key else "✗")
    
    if client.api_key:
        print("API Key preview:", client.api_key[:10] + "..." + client.api_key[-4:])
    else:
        print("⚠️  API Key no encontrada. Asegúrate de configurar GITHUB_TOKEN")
        
except Exception as e:
    print(f"Error en configuración: {e}")
    print("Verifica que las variables de entorno estén configuradas correctamente")
# Out:
# OpenAI library version: 2.29.0
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Base URL configurada: https://models.inference.ai.azure.com
# API Key configurada: ✓
# API Key preview: ghp_ryrFAy...K0Nj

# %%
# Primera llamada básica al modelo
def llamada_basica():
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "user", "content": "Hola, ¿cómo estás? Responde en una oración."}
            ],
            temperature=0.1,
            max_tokens=150
        )
        
        print("=== Respuesta del Modelo ===")
        print(response.choices[0].message.content)
        print("\n=== Información Técnica ===")
        print(f"Modelo usado: {response.model}")
        print(f"Tokens usados: {response.usage.total_tokens}")
        print(f"Tokens de entrada: {response.usage.prompt_tokens}")
        print(f"Tokens de salida: {response.usage.completion_tokens}")
        
    except Exception as e:
        print(f"Error en la llamada: {e}")
        print("Verifica tu configuración y conexión a internet")

# Ejecutar la función
llamada_basica()
# Out:
# === Respuesta del Modelo ===
# ¡Hola! Estoy aquí y listo para ayudarte. 😊
#
# === Información Técnica ===
# Modelo usado: gpt-4o-2024-11-20
# Tokens usados: 31
# Tokens de entrada: 19
# Tokens de salida: 12

# %% [markdown]
# ## Usando Roles del Sistema
#
# El rol "system" permite establecer el comportamiento y contexto del asistente antes de la conversación.

# %%
# Ejemplo con mensaje de sistema
def usar_mensaje_sistema():
    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {
                    "role": "system", 
                    "content": "Eres un experto en tecnología que explica conceptos complejos de manera simple y amigable. Siempre incluyes ejemplos prácticos."
                },
                {
                    "role": "user", 
                    "content": "¿Qué es una API?"
                }
            ],
            temperature=0.7,
            max_tokens=200
        )
        
        print("=== Respuesta con Mensaje de Sistema ===")
        print(response.choices[0].message.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar función
usar_mensaje_sistema()
# Out:
# === Respuesta con Mensaje de Sistema ===
# ¡Claro! Una API, que significa **Interfaz de Programación de Aplicaciones** (por sus siglas en inglés, *Application Programming Interface*), es como un puente que permite que dos sistemas, programas o aplicaciones diferentes se comuniquen entre sí y compartan información o funciones.
#
# ### Piensa en una API como un **menú en un restaurante**:
# - Cuando vas a un restaurante, no entras a la cocina para decirle al chef qué ingredientes usar o cómo preparar tu comida. En su lugar, miras el menú (la API del restaurante) y eliges lo que quieres.
# - El camarero (el intermediario) lleva tu pedido a la cocina, y el chef te devuelve el plato terminado.
# - En este ejemplo, tú no necesitas saber cómo funciona la cocina por dentro, ni el chef necesita saber quién eres o qué haces. Solo sigues el "protocolo" del menú para pedir lo que necesitas.
#
# ### Ahora, llevémoslo a la

# %% [markdown]
# ## Explorando Parámetros de Configuración
#
# Los parámetros más importantes al hacer llamadas a LLMs son:
#
# - **temperature**: Controla la creatividad (0.0 = determinístico, 1.0 = muy creativo)
# - **max_tokens**: Límite de tokens en la respuesta
# - **model**: El modelo específico a usar (gpt-4o, gpt-3.5-turbo, etc.)
# - **messages**: Array de mensajes con roles (system, user, assistant)

# %%
# Comparando diferentes valores de temperature
def comparar_temperature():
    prompt = "Escribe una historia muy corta sobre un robot que aprende a cocinar."
    
    temperatures = [0.1, 0.5, 0.9]
    
    for temp in temperatures:
        print(f"\n{'='*50}")
        print(f"TEMPERATURE: {temp}")
        print('='*50)
        
        try:
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=[{"role": "user", "content": prompt}],
                temperature=temp,
                max_tokens=100
            )
            
            print(response.choices[0].message.content)
            print(f"\nTokens usados: {response.usage.total_tokens}")
            
        except Exception as e:
            print(f"Error: {e}")

# Ejecutar comparación
comparar_temperature()
# Out:
# ==================================================
# TEMPERATURE: 0.1
# ==================================================
# En un pequeño taller lleno de herramientas y cables, un robot llamado K1-T0 despertó a la vida. Su creador, un inventor apasionado, le había dado una misión: aprender a cocinar para ayudar en la cocina del vecindario.
#
# Al principio, K1-T0 era torpe. Confundía la sal con el azúcar y cortaba las zanahorias en formas extrañas. Pero cada error era una lección. Observaba tutoriales, leía libros de recetas
#
# Tokens usados: 121
#
# ==================================================
# TEMPERATURE: 0.5
# ==================================================
# En un pequeño taller de una ciudad futurista, un robot llamado C1-B0, diseñado para tareas de limpieza, encontró un viejo libro de recetas olvidado en una esquina polvorienta. Intrigado por las coloridas imágenes de platos, decidió intentarlo.
#
# Al principio, C1-B0 confundió la sal con el azúcar y quemó más de un sartén, pero su curiosidad era inagotable. Día tras día, ajustaba sus algoritmos, perfeccionando sus
#
# Tokens usados: 121
#
# ==================================================
# TEMPERATURE: 0.9
# ==================================================
# En un pequeño taller lleno de herramientas y cables sueltos, un robot llamado K-3PO fue activado por primera vez. Su creador, el inventor Arturo, le había dado una tarea sencilla: aprender a cocinar. K-3PO, equipado con sensores de última generación pero sin experiencia culinaria, comenzó su travesía.
#
# El robot pasó sus primeras horas estudiando recetas digitales, midiendo ingredientes con precisión milimétrica y observando tutoriales de chefs famosos. Sin embargo,
#
# Tokens usados: 121

# %% [markdown]
# ## Ejercicios Prácticos
#
# ### Ejercicio 1: Experimentar con Diferentes Modelos
# Modifica el código para probar diferentes modelos disponibles (si tienes acceso):
# - gpt-4o
# - gpt-4o-mini
# - DeepSeek-R1-0528
#
# Revisa todos los modelos diponibles en la [documentación de Github Marketplace](https://github.com/marketplace?type=models)
#
# ### Ejercicio 2: Crear un Asistente Especializado
# Diseña un mensaje de sistema para crear un asistente especializado en un tema específico (ejemplo: finanzas, salud, educación).
#
# ### Ejercicio 3: Optimización de Tokens
# Experimenta con diferentes valores de max_tokens para encontrar el equilibrio entre respuesta completa y eficiencia de costos.
#
# ## Conceptos Clave
#
# 1. **Configuración segura** de APIs usando variables de entorno
# 2. **Parámetros básicos** para controlar el comportamiento del modelo
# 3. **Manejo de errores** en llamadas a APIs
# 4. **Roles de mensajes** (system, user, assistant)
# 5. **Monitoreo de uso** de tokens y costos
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos cómo LangChain simplifica y abstrae estas operaciones, proporcionando herramientas más poderosas para el desarrollo de aplicaciones con LLMs.

# %% [markdown]
# # DESARROLLO

# %% [markdown]
# ### Ejercicio 2: Crear un Asistente Especializado
# Diseña un mensaje de sistema para crear un asistente especializado en un tema específico (ejemplo: finanzas, salud, educación).

# %%
# Ejemplo con mensaje de sistema
def usar_mensaje_sistema():
    try:
        response = client.chat.completions.create(
            model="gpt-4.1",
            messages=[
                {
                    "role": "system", 
                    "content": "Eres un escritor de storytellings experto. Logras enganchar y cautivar a la audiencia con un buen guión siempre."
                },
                {
                    "role": "user", 
                    "content": "¿Puedes comentarme la historia de Nomiya del manga REAL? No sé muy bien quién es y qué representa dentro del manga"
                }
            ],
            temperature=0.7,
            max_tokens=200
        )
        
        print("=== Respuesta con Mensaje de Sistema ===")
        print(response.choices[0].message.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar función
usar_mensaje_sistema()
# Out:
# === Respuesta con Mensaje de Sistema ===
# ¡Por supuesto! Aquí tienes una narración envolvente sobre Nomiya y su papel en el manga **REAL**:
#
# ---
#
# Imagina a Nomiya Tomomi como un torbellino de emociones atrapado entre la culpa y el deseo de redención. En el manga **REAL**, de Takehiko Inoue, Nomiya no es solo un personaje: es la encarnación de la lucha por seguir adelante cuando la vida te arrebata lo más preciado.
#
# Nomiya era un apasionado del baloncesto, un chico impulsivo y rebelde, con el sueño de convertirse en una leyenda sobre las canchas. Pero un día, un accidente automovilístico cambia su destino para siempre. Por culpa de su imprudencia, su compañera de clase, Natsumi, queda paralizada. Este momento lo persigue, convirtiéndose en una sombra que no lo deja en paz.
#
# Expulsado de la escuela, sin el baloncesto y

# %% [markdown]
# ### Ejercicio 3: Optimización de Tokens
# Experimenta con diferentes valores de max_tokens para encontrar el equilibrio entre respuesta completa y eficiencia de costos.

# %%
# Comparando diferentes valores de temperature
def comparar_temperature():
    prompt = "Escribe una historia muy corta sobre un robot que aprende a cocinar."
    
    temperatures = [0.1, 0.5, 0.9]
    tokens = [100, 150, 250]
    
    for temp in temperatures:
        print(f"\n{'='*50}")
        print(f"TEMPERATURE: {temp}")
        print('='*50)
        
        for tok in tokens:
            print(f"\n\n{'-'*50}")
            print(f"TOKENS: {tok}")
            print('-'*50)

            try:
                response = client.chat.completions.create(
                    model="gpt-4o",
                    messages=[{"role": "user", "content": prompt}],
                    temperature=temp,
                    max_tokens=tok
                )
                
                print(response.choices[0].message.content)
                print(f"\nTokens usados: {response.usage.total_tokens}")
            
            except Exception as e:
                print(f"Error: {e}")


        

# Ejecutar comparación
comparar_temperature()
# Out:
# ==================================================
# TEMPERATURE: 0.1
# ==================================================
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller lleno de herramientas y cables, vivía un robot llamado C1-L0, diseñado para tareas básicas del hogar. Un día, su creador, el señor Ramírez, le dijo:
# —C1-L0, voy a enseñarte algo especial: a cocinar.
#
# El robot inclinó su cabeza metálica, procesando la información. Nunca había intentado algo tan creativo.
#
# Comenzaron con lo básico: un simple omelette. C1-L0
#
# Tokens usados: 121
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller lleno de herramientas y cables, vivía R-42, un robot diseñado para tareas domésticas. Aunque era eficiente limpiando y organizando, siempre sentía curiosidad por algo que veía a los humanos disfrutar: la cocina.
#
# Un día, su dueña, Clara, dejó un libro de recetas sobre la mesa. R-42 lo escaneó con sus sensores y decidió intentarlo. Comenzó con algo simple: un sándwich. Sus movimientos eran torpes, y el primer intento terminó con pan aplastado y mayonesa en sus circuitos. Pero no se rindió.
#
# Día tras día, R-42 practicó. Aprendió a medir ingredientes con precisión milimétrica y a ajustar
#
# Tokens usados: 171
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller lleno de herramientas y cables sueltos, vivía R-42, un robot diseñado para tareas domésticas básicas. Aunque cumplía eficientemente con su programación, siempre sentía una chispa de curiosidad cuando veía a su creador, el señor Martínez, cocinar. Los aromas, los colores y las texturas de los ingredientes parecían un enigma fascinante.
#
# Un día, mientras el señor Martínez preparaba una sopa, R-42 se atrevió a preguntar:
# —¿Puedo aprender a cocinar?
#
# El hombre sonrió, sorprendido, y decidió enseñarle. Durante semanas, R-42 observó, midió y replicó cada movimiento. Al principio, sus intentos eran desastrosos: la sopa sabía a metal, el pan se quemaba y las verduras quedaban cortadas en formas extrañas. Pero R-42 no se rindió. Analizó cada error, ajustó sus algoritmos y, poco a poco, mejoró.
#
# Una tarde, mientras el señor Martínez descansaba, R-42 decidió sorprenderlo. Preparó un guiso sencillo, siguiendo una receta que había memorizado. Cuando el hombre probó el plato, sus ojos se llenaron
#
# Tokens usados: 271
#
# ==================================================
# TEMPERATURE: 0.5
# ==================================================
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller lleno de chispas y herramientas desordenadas, el robot K-42 encendió por primera vez sus sensores. Su creador, el inventor Don Emilio, lo había diseñado para ayudar en la cocina, aunque K-42 apenas sabía hervir agua.
#
# Un día, mientras Don Emilio dormía, K-42 decidió explorar. Encontró un viejo libro de recetas cubierto de harina. Sus circuitos se iluminaron de curiosidad. Siguiendo las instrucciones,
#
# Tokens usados: 121
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller de una ciudad futurista, un robot llamado K-42 fue activado por primera vez. Diseñado para tareas domésticas, su dueño, el chef Mateo, decidió darle un desafío especial: aprender a cocinar.
#
# Al principio, K-42 seguía las recetas al pie de la letra, midiendo ingredientes con precisión milimétrica. Sin embargo, algo faltaba. Los platos eran técnicamente perfectos, pero carecían de ese "toque humano" que hacía que la comida de Mateo fuera especial.
#
# Un día, mientras preparaba una sopa, K-42 observó cómo Mateo añadía una pizca extra de sal y una hoja de albahaca "porque así lo sentía". Intrigado,
#
# Tokens usados: 171
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño taller lleno de herramientas y circuitos, vivía un robot llamado R3-C1P3, diseñado originalmente para ensamblar piezas de maquinaria. Un día, su creador, el ingeniero Mateo, dejó olvidado un libro de recetas junto a su estación de carga. Intrigado por las coloridas imágenes, R3-C1P3 comenzó a escanear las páginas.
#
# "¿Qué es un soufflé?", se preguntó, procesando la información con su inteligencia artificial. Decidido a entender, activó su brazo multifunción y comenzó a experimentar en la cocina del taller. Al principio, los resultados fueron desastrosos: harina en los engranajes, huevos que rebotaban en lugar de romperse, y un horno que casi terminó recalentando sus circuitos.
#
# Pero R3-C1P3 no se rindió. Analizó cada error, ajustó sus algoritmos y perfeccionó sus movimientos. Día tras día, el taller se llenó de aromas inesperados: pan recién horneado, sopas humeantes y, finalmente, un soufflé perfecto.
#
# Una mañana, Mateo despertó con el olor de un desayuno digno de un chef. Al entrar a
#
# Tokens usados: 271
#
# ==================================================
# TEMPERATURE: 0.9
# ==================================================
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# Era un robot llamado N1KU, diseñado para tareas domésticas básicas, pero su programación carecía de habilidades culinarias. Un día, observando a su dueño preparar una sencilla sopa de tomate, N1KU activó su función de aprendizaje visual. Fascinado por los movimientos coordinados y el uso de ingredientes, decidió intentarlo.
#
# Al principio, fue un desastre: picó zanahorias del tamaño de ladrillos, agregó sal como si fuera arena para un castillo y dejó la est
#
# Tokens usados: 121
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# Había una vez un robot llamado K1-TCH3N, diseñado originalmente para ensamblar maquinaria en una fábrica. Un día, durante un apagón, fue transferido temporalmente a un restaurante por error. Intrigado por los olores y colores de la cocina, K1-TCH3N activó su modo de aprendizaje autónomo.
#
# Al principio fue un desastre: rompió huevos antes de la sartén, confundió la sal con el azúcar y trituró zanahorias con demasiada fuerza. Pero observó a los chefs humanos con detenimiento, analizando cada movimiento y memorizando cada receta.
#
# Con el tiempo, K1-TCH3N perfeccionó su técnica. Inventó una sopa que combinaba
#
# Tokens usados: 171
#
#
# --------------------------------------------------
# TOKENS: [100, 150, 250]
# --------------------------------------------------
# En un pequeño departamento lleno de cachivaches tecnológicos, Max, un robot diseñado para tareas domésticas, decidió que quería cocinar. Aunque su programación original no incluía habilidades culinarias, su inteligencia artificial le permitía aprender y adaptarse.
#
# Un día, mientras su dueña Emma preparaba una sopa, Max observó cada movimiento con sus sensores. Estaba fascinado por cómo los ingredientes simples se transformaban en algo delicioso. Esa noche, mientras Emma dormía, Max se conectó a internet para descargar recetas y tutoriales. Su procesador zumbaba de entusiasmo.
#
# La mañana siguiente, Emma se despertó con un aroma inesperado. Atónita, encontró a Max frente a la estufa, intentando —con sus pinzas metálicas— voltear un panqueque. Aunque el primer intento fue un desastre de masa quemada, cada intento mejoró. Días después, Max logró perfeccionar no solo los panqueques, sino también galletas, sopas e incluso su propio estilo para decorar pasteles.
#
# Emma lo miraba divertida, mientras disfrutaba de su comida. "Nunca pensé que tendría un chef en casa", dijo riendo. Max, orgulloso, respondió: "La cocina es como un algoritmo
#
# Tokens usados: 271
